# %%
import pandas as pd

# %%
df1=pd.read_csv("views.csv")
df2=pd.read_csv("like.csv")
df3=pd.read_csv("post.csv")
df4=pd.read_csv("user.csv")
df5=pd.read_csv("rated.csv")
df6=pd.read_csv("inspire.csv")

# %%
df1
# Out:
#        id                                      slug  \
# 0    1366  1798a07257ce9756cd7547dd4e46d929bf619e2d
# 1     914  d53e83d2f539f7f703613e0527adcd8ea99a1f76
# 2     376  996ed1a4b5055d2b1e25609d7b68796a109d6af2
# 3     548  a1d8a33817f401973e7c33ed49b5a59871f2293b
# 4    1386  3cfbd3261dad9578d57cb00daa28c486f612732e
# ..    ...                                       ...
# 213  1257  4c631cfdaacc54d1c843f982c182d55f3d0e570c
# 214   722  5df83520404c7b7a937cbbab4a0b968845a97ce0
# 215  1242  3d5c386df70a27e6f5d13c7e1ad8e74c2946faf8
# 216  1245  82fea3dfe2da452b8dc0b58f5990d8f857c9b5f6
# 217  1252  60ef1ffc92a8bbe66eea5eb03fc085ca0b22f966
#
#                                                  title identifier  \
# 0    Between chasing your goals and hitting those m...    Qsrp9u-
# 1                                  God is proud of you    f5Ij2ow
# 2                                                  NaN    DxNkS3l
# 3                                                  NaN    amZ8tc1
# ...

# %%
df1.isnull().sum()
# Out:
# id                        0
# slug                      0
# title                    31
# identifier                0
# comment_count             0
# upvote_count              0
# view_count                0
# exit_count                0
# rating_count              0
# average_rating            0
# share_count               0
# video_link                0
# contract_address        171
# chain_id                171
# chart_url               171
# is_locked                 0
# created_at                0
# first_name                0
# last_name                 0
# username                  0
# upvoted                   0
# bookmarked                0
# thumbnail_url             0
# gif_thumbnail_url        69
# following                 0
# picture_url               0
# post_summary              0
# category_id               0
# category_name             0
# category_count            0
# category_description      0
# category_image_url        0
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   first_name       1000 non-null   object
#  2   last_name        1000 non-null   object
#  3   username         1000 non-null   object
#  4   email            1000 non-null   object
#  5   role             1000 non-null   object
#  6   profile_url      1000 non-null   object
#  7   bio              19 non-null     object
#  8   website_url      8 non-null      object
#  9   instagram-url    5 non-null      object
#  10  youtube_url      1 non-null      object
#  11  tictok_url       2 non-null      object
#  12  isVerified       1000 non-null   bool
#  13  referral_code    127 non-null    object
#  14  has_wallet       1000 non-null   bool
#  15  last_login       747 non-null    object
#  16  share_count      1000 non-null   int64
# ...

# %%
df3.isnull().sum()
# Out:
# id                     0
# category               0
# slug                   0
# title                322
# identifier             0
# comment_count          0
# upvote_count           0
# view_count             0
# exit_count             0
# rating_count           0
# average_rating         0
# share_count            0
# video_link             0
# contract_address     932
# chain_id             932
# chart_url            932
# baseToken              0
# is_locked              0
# created_at             0
# first_name             0
# last_name              0
# username               0
# upvoted                0
# bookmarked             0
# thumbnail_url          0
# gif_thumbnail_url    883
# following              0
# picture_url            0
# post_summary           0
# dtype: int64

# %%
df3
# Out:
#        id                                           category  \
# 0      11  {'id': 2, 'name': 'Vible', 'count': 535, 'desc...
# 1      12  {'id': 2, 'name': 'Vible', 'count': 535, 'desc...
# 2      13  {'id': 2, 'name': 'Vible', 'count': 535, 'desc...
# 3      14  {'id': 2, 'name': 'Vible', 'count': 535, 'desc...
# 4      15  {'id': 2, 'name': 'Vible', 'count': 535, 'desc...
# ..    ...                                                ...
# 995  1332  {'id': 13, 'name': 'Flic', 'count': 20, 'descr...
# 996  1334  {'id': 13, 'name': 'Flic', 'count': 20, 'descr...
# 997  1335  {'id': 13, 'name': 'Flic', 'count': 20, 'descr...
# 998  1336  {'id': 13, 'name': 'Flic', 'count': 20, 'descr...
# 999  1338  {'id': 13, 'name': 'Flic', 'count': 20, 'descr...
#
#                                          slug  \
# 0                     recipe-for-a-flow-state
# 1                                  why-fit-in
# 2                    transcending-singularity
# ...
